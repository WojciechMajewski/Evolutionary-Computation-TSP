# %%
results = ""
results = r"C:\Users\wojci\Documents\GitHub\Evolutionary-Computation-TSP\LSN_results_LS.txt"

# %%
with open(results) as f:
    text = f.read()

# %%
print(text)
# Out:
# DATASET A
#
# MSLS
# Best, Average, Worst scores:
# 74723 75237.4 75766
# 15, 117, 53, 62, 195, 22, 55, 36, 132, 128, 181, 113, 74, 163, 61, 71, 20, 64, 185, 116, 27, 147, 96, 59, 143, 159, 164, 178, 19, 0, 149, 50, 43, 77, 4, 192, 199, 174, 137, 41, 177, 1, 75, 189, 109, 134, 119, 130, 152, 11, 160, 106, 48, 26, 8, 124, 80, 14, 111, 31, 73, 12, 94, 72, 190, 98, 156, 6, 66, 112, 95, 169, 51, 135, 99, 101, 126, 60, 167, 186, 127, 88, 153, 175, 114, 121, 91, 161, 76, 21, 194, 79, 87, 141, 144, 102, 154, 81, 171, 108
# Time: 306634ms
#
# LSN
# Best, Average, Worst scores:
# 73314 73806.4 74184
# ...
